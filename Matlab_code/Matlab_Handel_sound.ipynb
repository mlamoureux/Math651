% %%
load handel

% %%
size(x)
% Out:
% Undefined function or variable 'x'.

% %%
size(y)
% Out:
% ans =
%
%        73113           1

% %%
plot(y)

% %%
sound(y,Fs)

% %%
Fs
% Out:
% Fs =
%
%         8192

% %%
plot(log(abs(fft(y))))
